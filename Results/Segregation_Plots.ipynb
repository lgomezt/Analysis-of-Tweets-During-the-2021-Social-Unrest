# %%
# Mathematical and Data Managment
import numpy as np
import pandas as pd
from datetime import datetime, timedelta

# Data Visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter

# Settings for plots
plt.rcParams['font.family'] = 'cmr10'
plt.rcParams['mathtext.fontset'] = 'cm'

#sns.set_style('white')

# %%
group_segregation = pd.read_pickle('/mnt/disk2/Data/Pickle/group_segregation.pkl')
global_segregation = pd.read_pickle('/mnt/disk2/Data/Pickle/global_segregation.pkl')
# Resetting index to make 'Date' a column for Seaborn's use
df = group_segregation.reset_index()

# %% [markdown]
# # Desagregated Measures (Group Level)

# %%
group_segregation.head()
# Out:
#                             Classic Freeman  Attention to Others  \
# Date       Political Label
# 2021-04-28 Centro                  0.231295             0.637107
#            Derecha                 0.797677             0.338138
#            Izquierda               0.573422             0.464827
#            Sin Clasificar          0.291349             0.602460
# 2021-04-29 Centro                  0.207262             0.603253
#
#                             Other's Attention  Attention From Izquierda To  \
# Date       Political Label
# 2021-04-28 Centro                    1.141433                     1.585731
#            Derecha                   0.108538                     0.065723
#            Izquierda                 0.134231                     1.578295
#            Sin Clasificar            4.205248                     0.392408
# 2021-04-29 Centro                    1.211583                     1.710093
#
#                             Attention From Derecha To  \
# Date       Political Label
# 2021-04-28 Centro                            0.844380
#            Derecha                           4.097602
#            Izquierda                         0.065587
#            Sin Clasificar                    0.682009
# 2021-04-29 Centro                            0.936834
#
#                             Attention From Centro To  \
# Date       Political Label
# 2021-04-28 Centro                           5.189496
#            Derecha                          0.356637
#            Izquierda                        0.643164
#            Sin Clasificar                   0.813383
# 2021-04-29 Centro                           5.756704
#
#                             Attention From Sin Clasificar To  \
# Date       Political Label
# 2021-04-28 Centro                                   1.083448
#            Derecha                                  0.562548
#            Izquierda                                0.537307
#            Sin Clasificar                           2.110595
# 2021-04-29 Centro                                   1.430013
#
#                             Attention Izquierda Took From  \
# Date       Political Label
# 2021-04-28 Centro                                0.560056
#            Derecha                               0.053359
#            Izquierda                             1.578295
#            Sin Clasificar                        0.059469
# 2021-04-29 Centro                                0.566692
#
#                             Attention Derecha Took From  \
# Date       Political Label
# 2021-04-28 Centro                              0.381721
#            Derecha                             4.097602
#            Izquierda                           0.080784
#            Sin Clasificar                      0.076531
# 2021-04-29 Centro                              0.349552
#
#                             Attention Centro Took From  \
# Date       Political Label
# 2021-04-28 Centro                             5.189496
#            Derecha                            0.788893
#            Izquierda                          1.821039
#            Sin Clasificar                     0.137711
# 2021-04-29 Centro                             5.756704
#
#                             Attention Sin Clasificar Took From  \
# Date       Political Label
# 2021-04-28 Centro                                     6.399353
#            Derecha                                    5.013155
#            Izquierda                                  3.545422
#            Sin Clasificar                             2.110595
# 2021-04-29 Centro                                     6.044028
#
#                             Non Weighted Assortativity  \
# Date       Political Label
# 2021-04-28 Centro                             0.157806
#            Derecha                            0.794928
#            Izquierda                          0.558983
#            Sin Clasificar                     0.033214
# 2021-04-29 Centro                             0.150752
#
#                             Normal Weighted Assortativity  \
# Date       Political Label
# 2021-04-28 Centro                                0.250145
#            Derecha                               0.752882
#            Izquierda                             0.571562
#            Sin Clasificar                        0.187617
# 2021-04-29 Centro                                0.260061
#
#                             Weighted Assortativity  Homiphily Index  \
# Date       Political Label
# 2021-04-28 Centro                         0.961728         0.401065
#            Derecha                        1.042385         0.748014
#            Izquierda                      1.100028         0.762949
#            Sin Clasificar                 0.951325         0.520936
# 2021-04-29 Centro                         1.003800         0.413519
#
#                             Inbreeding Homiphily Index
# Date       Political Label
# 2021-04-28 Centro                             0.337611
#            Derecha                            0.691135
#            Izquierda                          0.367111
#            Sin Clasificar                     0.470878
# 2021-04-29 Centro                             0.351384

# %%
group_segregation.tail(10)
# Out:
#                             Classic Freeman  Attention to Others  \
# Date       Political Label
# 2021-06-25 Izquierda               0.646354             0.475388
#            Sin Clasificar          0.267316             0.612883
# 2021-06-26 Centro                  0.258725             0.519462
#            Derecha                 0.675307             0.341742
#            Izquierda               0.640307             0.475427
#            Sin Clasificar          0.202769             0.598516
# 2021-06-27 Centro                  0.270476             0.529291
#            Derecha                 0.683874             0.363173
#            Izquierda               0.628428             0.462922
#            Sin Clasificar          0.166591             0.605494
#
#                             Other's Attention  Attention From Izquierda To  \
# Date       Political Label
# 2021-06-25 Izquierda                 0.082955                     1.752265
#            Sin Clasificar            4.990913                     0.342933
# 2021-06-26 Centro                    1.260522                     1.555358
#            Derecha                   0.112576                     0.101550
#            Izquierda                 0.086081                     1.743531
#            Sin Clasificar            5.385508                     0.382895
# 2021-06-27 Centro                    1.225503                     1.429602
#            Derecha                   0.110086                     0.096332
#            Izquierda                 0.085024                     1.757882
#            Sin Clasificar            5.518237                     0.391238
#
#                             Attention From Derecha To  \
# Date       Political Label
# 2021-06-25 Izquierda                         0.049696
#            Sin Clasificar                    0.471389
# 2021-06-26 Centro                            1.159051
#            Derecha                           4.323940
#            Izquierda                         0.052025
#            Sin Clasificar                    0.489782
# 2021-06-27 Centro                            1.214467
#            Derecha                           4.327294
#            Izquierda                         0.052137
#            Sin Clasificar                    0.527876
#
#                             Attention From Centro To  \
# Date       Political Label
# 2021-06-25 Izquierda                        0.490581
#            Sin Clasificar                   0.607767
# 2021-06-26 Centro                           6.111031
#            Derecha                          0.387937
#            Izquierda                        0.511822
#            Sin Clasificar                   0.593775
# 2021-06-27 Centro                           6.000821
#            Derecha                          0.405771
#            Izquierda                        0.506121
#            Sin Clasificar                   0.616282
#
#                             Attention From Sin Clasificar To  \
# Date       Political Label
# 2021-06-25 Izquierda                                0.425212
#            Sin Clasificar                           1.782785
# 2021-06-26 Centro                                   1.334207
#            Derecha                                  0.649364
#            Izquierda                                0.425357
#            Sin Clasificar                           1.796642
# 2021-06-27 Centro                                   1.331308
#            Derecha                                  0.599569
#            Izquierda                                0.457236
#            Sin Clasificar                           1.770678
#
#                             Attention Izquierda Took From  \
# Date       Political Label
# 2021-06-25 Izquierda                             1.752265
#            Sin Clasificar                        0.031812
# 2021-06-26 Centro                                0.375523
#            Derecha                               0.045787
#            Izquierda                             1.743531
#            Sin Clasificar                        0.031726
# 2021-06-27 Centro                                0.359445
#            Derecha                               0.045109
#            Izquierda                             1.757882
#            Sin Clasificar                        0.034236
#
#                             Attention Derecha Took From  \
# Date       Political Label
# 2021-06-25 Izquierda                           0.101378
#            Sin Clasificar                      0.062586
# 2021-06-26 Centro                              0.323412
#            Derecha                             4.323940
#            Izquierda                           0.115387
#            Sin Clasificar                      0.055033
# 2021-06-27 Centro                              0.333077
#            Derecha                             4.327294
#            Izquierda                           0.111342
#            Sin Clasificar                      0.051888
#
#                             Attention Centro Took From  \
# Date       Political Label
# 2021-06-25 Izquierda                          2.404009
#            Sin Clasificar                     0.130642
# 2021-06-26 Centro                             6.111031
#            Derecha                            1.390297
#            Izquierda                          2.119886
#            Sin Clasificar                     0.135633
# 2021-06-27 Centro                             6.000821
#            Derecha                            1.479523
#            Izquierda                          2.012971
#            Sin Clasificar                     0.140360
#
#                             Attention Sin Clasificar Took From  \
# Date       Political Label
# 2021-06-25 Izquierda                                  4.583762
#            Sin Clasificar                             1.782785
# 2021-06-26 Centro                                     5.840911
#            Derecha                                    5.779182
#            Izquierda                                  5.133587
#            Sin Clasificar                             1.796642
# 2021-06-27 Centro                                     5.845422
#            Derecha                                    6.099638
#            Izquierda                                  5.225169
#            Sin Clasificar                             1.770678
#
#                             Non Weighted Assortativity  \
# Date       Political Label
# 2021-06-25 Izquierda                          0.673618
#            Sin Clasificar                     0.054784
# 2021-06-26 Centro                             0.272829
#            Derecha                            0.770746
#            Izquierda                          0.667598
#            Sin Clasificar                     0.050785
# 2021-06-27 Centro                             0.262988
#            Derecha                            0.762813
#            Izquierda                          0.653804
#            Sin Clasificar                     0.048566
#
#                             Normal Weighted Assortativity  \
# Date       Political Label
# 2021-06-25 Izquierda                             0.586056
#            Sin Clasificar                        0.190056
# 2021-06-26 Centro                                0.307811
#            Derecha                               0.737591
#            Izquierda                             0.580703
#            Sin Clasificar                        0.181285
# 2021-06-27 Centro                                0.309879
#            Derecha                               0.725212
#            Izquierda                             0.583358
#            Sin Clasificar                        0.175555
#
#                             Weighted Assortativity  Homiphily Index  \
# Date       Political Label
# 2021-06-25 Izquierda                      1.016446         0.746953
#            Sin Clasificar                 0.973020         0.581065
# 2021-06-26 Centro                         0.856802         0.537404
#            Derecha                        0.935503         0.749217
#            Izquierda                      1.061922         0.747781
#            Sin Clasificar                 2.403712         0.588785
# 2021-06-27 Centro                         0.900627         0.517613
#            Derecha                        2.037782         0.732607
#            Izquierda                      0.869329         0.751687
#            Sin Clasificar                 0.701497         0.587879
#
#                             Inbreeding Homiphily Index
# Date       Political Label
# 2021-06-25 Izquierda                          0.324404
#            Sin Clasificar                     0.537290
# 2021-06-26 Centro                             0.488394
#            Derecha                            0.692611
#            Izquierda                          0.326615
#            Sin Clasificar                     0.545817
# 2021-06-27 Centro                             0.466507
#            Derecha                            0.672251
#            Izquierda                          0.337042
#            Sin Clasificar                     0.544816

# %%
fig, ax = plt.subplots(figsize=(13, 6))
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Classic Freeman', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=ax, marker='o')

# Axes settings
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.set_ylabel('')
ax.set_xlabel('')
ax.tick_params(axis='x', which='both', direction='out', length=6, width=1)

# Rotate x-ticks for better readability
plt.xticks(rotation=45)

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

# Title
plt.title('Classical Freeman Segregation Index', fontsize=18)

plt.show()
# Out:
# /tmp/ipykernel_308097/798792396.py:1: UserWarning: cmr10 font should ideally be used with mathtext, set axes.formatter.use_mathtext to True
#   fig, ax = plt.subplots(figsize=(13, 6))

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Attention to Others', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[0], marker='o', legend = False)

sns.lineplot(data=df, x='Date', y="Other's Attention", hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[1], marker='o')

# Axes settingsAttention to Others
for ax in axes:
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=6))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    ax.tick_params(axis = 'x', rotation = 45)
    ax.set_ylabel('')
    ax.set_xlabel('')
    #ax.set_ylim(0,0.5)

axes[0].set_title('Attention to Others Index')
axes[1].set_title('Attention from Others Index')

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

# Title
plt.suptitle('Attention given from one party to the rest', fontsize=18)

plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Attention From Izquierda To', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[0], marker='o', legend = False)

sns.lineplot(data=df, x='Date', y="Attention From Derecha To", hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[1], marker='o')

# Axes settings
for ax in axes:
    # Better readability of X axis
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=6))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    ax.tick_params(axis = 'x', rotation = 45)
    
    # Unnecesarry Titles
    ax.set_ylabel('')
    ax.set_xlabel('')
    
    # Set limits for indexes
    #ax.set_ylim(0,1.5)
    #ax.axhline(y=1, color='gray', linestyle='--', linewidth=1, alpha=0.7)

axes[0].set_title('Attention From Izquierda To:', fontsize=14)
axes[1].set_title('Attention From Derecha To:', fontsize=14)

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Attention From Centro To', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[0], marker='o', legend = False)

sns.lineplot(data=df, x='Date', y="Attention From Sin Clasificar To", hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[1], marker='o')

# Axes settings
for ax in axes:
    # Better readability of X axis
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=6))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    ax.tick_params(axis = 'x', rotation = 45)
    
    # Unnecesarry Titles
    ax.set_ylabel('')
    ax.set_xlabel('')
    
    # Set limits for indexes
    #ax.set_ylim(0,0.6)
    #ax.axhline(y=1, color='gray', linestyle='--', linewidth=1, alpha=0.7)

axes[0].set_title('Attention From Centro To:', fontsize=14)
axes[1].set_title('Attention From Sin Clasificar To:', fontsize=14)

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(13, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Homiphily Index', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=ax, marker='o')

# Axes settings
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.set_ylabel('')
ax.set_xlabel('')

# Rotate x-ticks for better readability
plt.xticks(rotation=45)

# Legend
#plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

# Title
plt.title('Homiphily Index', fontsize=18)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(13, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Inbreeding Homiphily Index', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=ax, marker='o')

# Axes settings
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.set_ylabel('')
ax.set_xlabel('')

# Rotate x-ticks for better readability
plt.xticks(rotation=45, ha = 'right')

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

# Title
plt.title('Inbreeding Homiphily Index', fontsize=18)

plt.show()

# %%
fig, axes = plt.subplots(1,2,figsize=(16, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Normal Weighted Assortativity', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[0], marker='o', legend = False)

sns.lineplot(data=df, x='Date', y="Weighted Assortativity", hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=axes[1], marker='o')

# Axes settings
for ax in axes:
    # Better readability of X axis
    ax.xaxis.set_major_locator(mdates.DayLocator(interval=6))
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
    ax.tick_params(axis = 'x', rotation = 45)
    
    # Unnecesarry Titles
    ax.set_ylabel('')
    ax.set_xlabel('')
    
    # Set limits for indexes
    #ax.set_ylim(0,0.6)
    #ax.axhline(y=1, color='gray', linestyle='--', linewidth=1, alpha=0.7)

axes[0].set_title('Assortativity using Normal Weight', fontsize=14)
axes[1].set_title('Assortativity using Number of Rts as weights:', fontsize=14)

# Legend
plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(13, 6))  # Increased size from (12,5) to (16,8)
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
# Plot
sns.lineplot(data=df, x='Date', y='Non Weighted Assortativity', hue='Political Label',
             palette=["forestgreen", "red", "darkblue", "purple"], ax=ax, marker='o')

# Axes settings
ax.xaxis.set_major_locator(mdates.DayLocator(interval=3))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%d-%m-%Y'))
ax.set_ylabel('')
ax.set_xlabel('')

# Rotate x-ticks for better readability
plt.xticks(rotation=45)

# Legend
#plt.legend(title='Political Label', bbox_to_anchor=(1, 1), loc='best')

# Title
plt.title('Non Weighted Assortativity', fontsize=18)

plt.show()

# %% [markdown]
# # Global Measures

# %%
global_segregation.head()
# Out:
#             Freeman Global  Normal Weighted Assortativity  \
# 2021-04-28        0.537315                       0.501600
# 2021-04-29        0.548880                       0.508322
# 2021-04-30        0.561385                       0.511913
# 2021-05-01        0.550820                       0.511692
# 2021-05-02        0.524167                       0.493515
#
#             Weighted Assortativity  Non Weighted Assortativity
# 2021-04-28                1.182048                    0.501394
# 2021-04-29                0.997113                    0.489940
# 2021-04-30                0.947548                    0.484228
# 2021-05-01               -1.844281                    0.467010
# 2021-05-02                0.792956                    0.449811

# %%
# Plotting using Seaborn with different colors for each category
fig, ax = plt.subplots(figsize = (12,5))
sns.lineplot(global_segregation, x = global_segregation.index, y ='Freeman Global', errorbar=None, ax =ax, marker='o', color = 'darkblue')
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
plt.xticks(rotation=45)
plt.title('Global Freeman Segregation (Directed, Unweighted)')
#plt.savefig("../Results/Global_Freeman_Unweighted.png")
plt.show()

# %%
# Plotting using Seaborn with different colors for each category
fig, ax = plt.subplots(figsize = (12,5))
sns.lineplot(global_segregation, x = global_segregation.index, y ='Normal Weighted Assortativity', errorbar=None, ax =ax, marker='o', color = 'darkblue')
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
plt.xticks(rotation=45)
plt.title('Assortativity Using Normalize Weights')
#plt.savefig("../Results/Global_Freeman_Unweighted.png")
plt.show()

# %%
# Plotting using Seaborn with different colors for each category
fig, ax = plt.subplots(figsize = (12,5))
sns.lineplot(global_segregation, x = global_segregation.index, y ='Weighted Assortativity', errorbar=None, ax =ax, marker='o', color = 'darkblue')
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
plt.xticks(rotation=45)
plt.title('Assortativity using Number of Rts as weights')
#plt.savefig("../Results/Global_Freeman_Unweighted.png")
plt.show()

# %%
# Plotting using Seaborn with different colors for each category
fig, ax = plt.subplots(figsize = (12,5))
sns.lineplot(global_segregation, x = global_segregation.index, y ='Non Weighted Assortativity', errorbar=None, ax =ax, marker='o', color = 'darkblue')
# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
plt.xticks(rotation=45)
plt.title('Assortativity Without Weights')
#plt.savefig("../Results/Global_Freeman_Unweighted.png")
plt.show()

# %% [markdown]
# # Study Event-like Plots

# %%
def study_event_df(group_segregation: pd.DataFrame, event:str, seg_index:str):
    # Study Event DataFrame (Like the group segregation but empty)
    study_events = group_segregation.copy()[[]].sort_index()
    
    # Get fixed values
    event_seg = group_segregation.loc[event, seg_index]
    event_seg = event_seg.to_dict()
    event_date = datetime.strptime(event, '%Y-%m-%d')
    
    # Get Days (X axis)
    study_events[f"days_from_{event}"] = group_segregation.index.get_level_values('Date') - event_date
    study_events[f"days_from_{event}"] = study_events[f"days_from_{event}"].dt.days
    
    # Get Segregation (Y axis)
    study_events['Segregation Deviation %'] = group_segregation.index.get_level_values('Political Label').map(event_seg)
    study_events['Segregation Deviation %'] = (group_segregation[seg_index] - study_events['Segregation Deviation %']) / study_events['Segregation Deviation %'] 
    
    # Prepare df
    study_events.reset_index(inplace=True)
    study_events.drop(columns='Date', inplace=True)

    return study_events, event

study_event_df(group_segregation,'2021-05-12', 'Classic Freeman')[0]
# Out:
#     Political Label  days_from_2021-05-12  Segregation Deviation %
# 0            Centro                   -14                -0.197547
# 1           Derecha                   -14                -0.030558
# 2         Izquierda                   -14                -0.021222
# 3    Sin Clasificar                   -14                 0.059965
# 4            Centro                   -13                -0.280927
# ..              ...                   ...                      ...
# 239  Sin Clasificar                    45                -0.262301
# 240          Centro                    46                -0.061611
# 241         Derecha                    46                -0.168867
# 242       Izquierda                    46                 0.072669
# 243  Sin Clasificar                    46                -0.393919
#
# [244 rows x 3 columns]

# %%
date = '2021-04-28'
categories = ['Izquierda', 'Derecha', 'Centro', 'Sin Clasificar']
study_events, starting_date = study_event_df(group_segregation, date, 'Classic Freeman')

# Plotting using Seaborn with different colors for each category
plot = sns.relplot(data = study_events, kind = 'line', marker='o',
            x = f'days_from_{starting_date}', y ='Segregation Deviation %',
            col='Political Label', hue='Political Label', col_wrap = 2,
            palette = ["darkblue", "red", "forestgreen", "purple"], legend=False)

# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
percentage_formatter = FuncFormatter(lambda x, pos: f'{x*100:.0f}%')

for ax, pol in zip(plot.axes.flatten(), categories):
    ax.axvline(x=0, color='gray', linestyle='--', alpha=0.2)
    ax.axhline(y=0, color='gray', linestyle='--', alpha=0.2)
    ax.set_xlabel('Number of days away from event')
    ax.set_title(pol)
    ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

title_font = {'size': 40, 'weight': 'bold'}
plot.figure.suptitle("Porcentual Deviation of Freeman Segregation (No Weights and Undirected, 3 Rolling Day)", y=1.03, fontdict=title_font)
subtitle_font = {'size': 12, 'weight': 'normal', 'style': 'italic'}
plot.figure.text(0.5, 1, f"Event ocurred on {starting_date}", ha='center', fontdict=subtitle_font)
#plt.savefig(f"../Results/Event_Study_Freeman_{starting_date}.png")
plt.show()

# %%
date = '2021-05-01'
categories = ['Izquierda', 'Derecha', 'Centro', 'Sin Clasificar']
study_events, starting_date = study_event_df(group_segregation, date, 'Attention to Others')

# Plotting using Seaborn with different colors for each category
plot = sns.relplot(data = study_events, kind = 'line', marker='o',
            x = f'days_from_{starting_date}', y ='Segregation Deviation %',
            col='Political Label', hue='Political Label', col_wrap = 2,
            palette = ["darkblue", "red", "forestgreen", "purple"], legend=False)

# Enable the use of Font
plt.rcParams['axes.formatter.use_mathtext'] = True
percentage_formatter = FuncFormatter(lambda x, pos: f'{x*100:.0f}%')

for ax, pol in zip(plot.axes.flatten(), categories):
    ax.axvline(x=0, color='gray', linestyle='--', alpha=0.2)
    ax.axhline(y=0, color='gray', linestyle='--', alpha=0.2)
    ax.set_xlabel('Number of days away from event')
    ax.set_title(pol)
    ax.yaxis.set_major_formatter(FuncFormatter(percentage_formatter))

title_font = {'size': 40, 'weight': 'bold'}
plot.figure.suptitle("Porcentual Deviation of Freeman Segregation (No Weights and Undirected, 3 Rolling Day)", y=1.03, fontdict=title_font)
subtitle_font = {'size': 12, 'weight': 'normal', 'style': 'italic'}
plot.figure.text(0.5, 1, f"Event ocurred on {starting_date}", ha='center', fontdict=subtitle_font)
#plt.savefig(f"../Results/Event_Study_Freeman_{starting_date}.png")

plt.show()
